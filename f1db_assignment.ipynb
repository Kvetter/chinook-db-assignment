# %%
# %load_ext sql

# %%
# %sql postgresql://appdev@data:5432/appdev
# Out:
# 'Connected: appdev@appdev'

# %% [markdown]
# ## On the table circuits report:
#
# * What type of indices exists for the table and why they are of that type (and not some other type)
# * The amount of space each index takes up
#
# There are three indices on the circuits table which are created on the position, the url and the primary key. The url and the primary key are btree's while the position is a gist structure. The position is a combination of the latitude and longitude, so with a gist stucture postgres is able to make more complicated comparisions, than just lager or smaller than. With geo space we also need to ask where we are compared to another location.
#
# The gist index on the position uses 8192 bytes of space
# The btree index on the primary key uses 16 kb of space
# The btree index on the url uses 16kb of spacemar

# %% [markdown]
# ## We are talent scouts looking to win over some of the best new drivers there are. But we don't want them too old! Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %sql SELECT drivers.surname, drivers.dob, milliseconds, races.name AS race_name, circuits.name AS circuits_name, races.date AS race_date FROM results JOIN drivers ON drivers.dob > '1980-01-01' AND results.position = 1 AND drivers.driverid = results.driverid JOIN races USING (raceid) JOIN circuits ON circuits.circuitid = races.circuitid ORDER BY drivers.dob DESC;
# Out:
# 199 rows affected.
# [('Verstappen', datetime.date(1997, 9, 30), 5401290, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2017, 10, 1)),
#  ('Verstappen', datetime.date(1997, 9, 30), 6100017, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2016, 5, 15)),
#  ('Bottas', datetime.date(1989, 8, 28), 4908523, 'Austrian Grand Prix', 'Red Bull Ring', datetime.date(2017, 7, 9)),
#  ('Bottas', datetime.date(1989, 8, 28), 5288743, 'Russian Grand Prix', 'Sochi Autodrom', datetime.date(2017, 4, 30)),
#  ('Ricciardo', datetime.date(1989, 7, 1), 7435573, 'Azerbaijan Grand Prix', 'Baku City Circuit', datetime.date(2017, 6, 25)),
#  ('Ricciardo', datetime.date(1989, 7, 1), 5076556, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2014, 8, 24)),
#  ('Ricciardo', datetime.date(1989, 7, 1), 5952830, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2014, 6, 8)),
#  ('Ricciardo', datetime.date(1989, 7, 1), 6785058, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2014, 7, 27)),
#  ('Ricciardo', datetime.date(1989, 7, 1), 5832776, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2016, 10, 2)),
#  ('Vettel', datetime.date(1987, 7, 3), 5788651, 'Korean Grand Prix', 'Korean International Circuit', datetime.date(2012, 10, 14)),
#  ('Vettel', datetime.date(1987, 7, 3), 5336242, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2012, 10, 7)),
#  ('Vettel', datetime.date(1987, 7, 3), 5710990, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2012, 4, 22)),
#  ('Vettel', datetime.date(1987, 7, 3), 7226144, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2012, 9, 23)),
#  ('Vettel', datetime.date(1987, 7, 3), 5986713, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2017, 7, 30)),
#  ('Vettel', datetime.date(1987, 7, 3), 4713352, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2013, 9, 8)),
#  ('Vettel', datetime.date(1987, 7, 3), 5760498, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2013, 4, 21)),
#  ('Vettel', datetime.date(1987, 7, 3), 5936681, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2013, 3, 24)),
#  ('Vettel', datetime.date(1987, 7, 3), 5204893, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2011, 8, 28)),
#  ('Vettel', datetime.date(1987, 7, 3), 4846172, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2011, 9, 11)),
#  ('Vettel', datetime.date(1987, 7, 3), 7146757, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2011, 9, 25)),
#  ('Vettel', datetime.date(1987, 7, 3), 5470744, 'Indian Grand Prix', 'Buddh International Circuit', datetime.date(2012, 10, 28)),
#  ('Vettel', datetime.date(1987, 7, 3), 5881994, 'Korean Grand Prix', 'Korean International Circuit', datetime.date(2011, 10, 16)),
#  ('Vettel', datetime.date(1987, 7, 3), 5435002, 'Indian Grand Prix', 'Buddh International Circuit', datetime.date(2011, 10, 30)),
#  ('Vettel', datetime.date(1987, 7, 3), 5472187, 'Indian Grand Prix', 'Buddh International Circuit', datetime.date(2013, 10, 27)),
#  ('Vettel', datetime.date(1987, 7, 3), 5209301, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2013, 10, 13)),
#  ('Vettel', datetime.date(1987, 7, 3), 4969328, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2009, 6, 21)),
#  ('Vettel', datetime.date(1987, 7, 3), 5633374, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2017, 4, 16)),
#  ('Vettel', datetime.date(1987, 7, 3), 5300443, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2009, 10, 4)),
#  ('Vettel', datetime.date(1987, 7, 3), 5643414, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2009, 11, 1)),
#  ('Vettel', datetime.date(1987, 7, 3), 6193701, 'Korean Grand Prix', 'Korean International Circuit', datetime.date(2013, 10, 6)),
#  ('Vettel', datetime.date(1987, 7, 3), 7153132, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2013, 9, 22)),
#  ('Vettel', datetime.date(1987, 7, 3), 5628412, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2010, 4, 4)),
#  ('Vettel', datetime.date(1987, 7, 3), 5976169, 'European Grand Prix', 'Valencia Street Circuit', datetime.date(2011, 6, 26)),
#  ('Vettel', datetime.date(1987, 7, 3), 5207494, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2008, 9, 14)),
#  ('Vettel', datetime.date(1987, 7, 3), 5051672, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2017, 3, 26)),
#  ('Vettel', datetime.date(1987, 7, 3), 6029571, 'European Grand Prix', 'Valencia Street Circuit', datetime.date(2010, 6, 27)),
#  ('Vettel', datetime.date(1987, 7, 3), 5022196, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2013, 8, 25)),
#  ('Vettel', datetime.date(1987, 7, 3), 6074711, 'German Grand Prix', 'Nürburgring', datetime.date(2013, 7, 7)),
#  ('Vettel', datetime.date(1987, 7, 3), 5427323, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2010, 10, 10)),
#  ('Vettel', datetime.date(1987, 7, 3), 5529143, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2013, 6, 9)),
#  ('Vettel', datetime.date(1987, 7, 3), 5591803, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2010, 11, 7)),
#  ('Vettel', datetime.date(1987, 7, 3), 5976837, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2010, 11, 14)),
#  ('Vettel', datetime.date(1987, 7, 3), 5370259, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2011, 3, 27)),
#  ('Vettel', datetime.date(1987, 7, 3), 5859832, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2011, 4, 10)),
#  ('Vettel', datetime.date(1987, 7, 3), 5417558, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2011, 5, 8)),
#  ('Vettel', datetime.date(1987, 7, 3), 5943301, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2011, 5, 22)),
#  ('Vettel', datetime.date(1987, 7, 3), 7778373, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2011, 5, 29)),
#  ('Vettel', datetime.date(1987, 7, 3), 6284340, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2017, 5, 28)),
#  ('Vettel', datetime.date(1987, 7, 3), 7282118, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2015, 9, 20)),
#  ('Vettel', datetime.date(1987, 7, 3), 6369985, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2015, 7, 26)),
#  ('Vettel', datetime.date(1987, 7, 3), 6065793, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2015, 3, 29)),
#  ('Vettel', datetime.date(1987, 7, 3), 5556300, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2013, 11, 24)),
#  ('Vettel', datetime.date(1987, 7, 3), 7063485, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2009, 4, 19)),
#  ('Vettel', datetime.date(1987, 7, 3), 5957148, 'United States Grand Prix', 'Circuit of the Americas', datetime.date(2013, 11, 17)),
#  ('Vettel', datetime.date(1987, 7, 3), 5886106, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2013, 11, 3)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6948950, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2016, 9, 18)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5561997, 'Russian Grand Prix', 'Sochi Autodrom', datetime.date(2016, 5, 1)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5933891, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2016, 4, 17)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5203333, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2016, 10, 9)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5614696, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2016, 4, 3)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6495565, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2016, 3, 20)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5910175, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2015, 11, 29)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5469090, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2015, 11, 15)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6155038, 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez', datetime.date(2015, 11, 1)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5786929, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2012, 4, 15)),
#  ('Rosberg', datetime.date(1985, 6, 27), 8272056, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2013, 5, 26)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5416930, 'Austrian Grand Prix', 'Red Bull Ring', datetime.date(2015, 6, 21)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6558420, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2015, 5, 24)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6072555, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2015, 5, 10)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5579456, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2013, 6, 30)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5402555, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2014, 11, 9)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6291058, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2016, 8, 28)),
#  ('Rosberg', datetime.date(1985, 6, 27), 4648089, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2016, 9, 4)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5622914, 'German Grand Prix', 'Hockenheimring', datetime.date(2014, 7, 20)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5274976, 'Austrian Grand Prix', 'Red Bull Ring', datetime.date(2014, 6, 22)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5572366, 'European Grand Prix', 'Baku City Circuit', datetime.date(2016, 6, 19)),
#  ('Rosberg', datetime.date(1985, 6, 27), 6567661, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2014, 5, 25)),
#  ('Rosberg', datetime.date(1985, 6, 27), 5578710, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2014, 3, 16)),
#  ('Maldonado', datetime.date(1985, 3, 9), 5949145, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2012, 5, 13)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5444200, 'German Grand Prix', 'Hockenheimring', datetime.date(2016, 7, 31)),
#  ('Hamilton', datetime.date(1985, 1, 7), 7242742, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2008, 5, 25)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5949440, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2008, 7, 6)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5480874, 'German Grand Prix', 'Hockenheimring', datetime.date(2008, 7, 20)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5517403, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2008, 10, 19)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6251292, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2007, 6, 10)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5469965, 'United States Grand Prix', 'Indianapolis Motor Speedway', datetime.date(2007, 6, 17)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5752991, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2007, 8, 5)),
#  ('Hamilton', datetime.date(1985, 1, 7), 7234579, 'Japanese Grand Prix', 'Fuji Speedway', datetime.date(2007, 9, 30)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5903876, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2009, 7, 26)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6966337, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2009, 9, 27)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5327620, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2010, 5, 30)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5633456, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2010, 6, 13)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5344268, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2010, 8, 29)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5818226, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2011, 4, 17)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5850334, 'German Grand Prix', 'Nürburgring', datetime.date(2011, 7, 24)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5831886, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2011, 11, 13)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5549586, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2012, 6, 10)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6065503, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2012, 7, 29)),
#  ('Hamilton', datetime.date(1985, 1, 7), 4781221, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2012, 9, 9)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5755269, 'United States Grand Prix', 'Circuit of the Americas', datetime.date(2012, 11, 18)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6149445, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2013, 7, 28)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6025974, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2014, 3, 30)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5982743, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2014, 4, 6)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5608338, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2014, 4, 20)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6065155, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2014, 5, 11)),
#  ('Hamilton', datetime.date(1985, 1, 7), 8812094, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2014, 7, 6)),
#  ('Hamilton', datetime.date(1985, 1, 7), 4750236, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2014, 9, 7)),
#  ('Hamilton', datetime.date(1985, 1, 7), 7204795, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2014, 9, 21)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6703021, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2014, 10, 5)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5510744, 'Russian Grand Prix', 'Sochi Autodrom', datetime.date(2014, 10, 12)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6004785, 'United States Grand Prix', 'Circuit of the Americas', datetime.date(2014, 11, 2)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5942619, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2014, 11, 23)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5514067, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2015, 3, 15)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5982008, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2015, 4, 12)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5705809, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2015, 4, 19)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5513145, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2015, 6, 7)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5487729, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2015, 7, 5)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5020387, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2015, 8, 23)),
#  ('Hamilton', datetime.date(1985, 1, 7), 4680688, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2015, 9, 6)),
#  ('Hamilton', datetime.date(1985, 1, 7), None, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2015, 9, 27)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5831024, 'Russian Grand Prix', 'Sochi Autodrom', datetime.date(2015, 10, 11)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6652703, 'United States Grand Prix', 'Circuit of the Americas', datetime.date(2015, 10, 25)),
#  ('Hamilton', datetime.date(1985, 1, 7), 7169133, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2016, 5, 29)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5465296, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2016, 6, 12)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5258107, 'Austrian Grand Prix', 'Red Bull Ring', datetime.date(2016, 7, 3)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5695831, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2016, 7, 10)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6030115, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2016, 7, 24)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5690616, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2008, 3, 16)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5892618, 'United States Grand Prix', 'Circuit of the Americas', datetime.date(2016, 10, 23)),
#  ('Hamilton', datetime.date(1985, 1, 7), 6031402, 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez', datetime.date(2016, 10, 30)),
#  ('Hamilton', datetime.date(1985, 1, 7), 10861335, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2016, 11, 13)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5884013, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', datetime.date(2016, 11, 27)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5856158, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2017, 4, 9)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5756497, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2017, 5, 14)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5585154, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2017, 6, 11)),
#  ('Hamilton', datetime.date(1985, 1, 7), 4887430, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2017, 7, 16)),
#  ('Hamilton', datetime.date(1985, 1, 7), 5082820, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2017, 8, 27)),
#  ('Hamilton', datetime.date(1985, 1, 7), 4532312, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2017, 9, 3)),
#  ('Hamilton', datetime.date(1985, 1, 7), 7403544, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2017, 9, 17)),
#  ('Kubica', datetime.date(1984, 12, 7), 5784227, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2008, 6, 8)),
#  ('Kovalainen', datetime.date(1981, 10, 19), 5847067, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2008, 8, 3)),
#  ('Alonso', datetime.date(1981, 7, 29), 5358531, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2005, 4, 3)),
#  ('Alonso', datetime.date(1981, 7, 29), 7036304, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2008, 9, 28)),
#  ('Alonso', datetime.date(1981, 7, 29), 5493736, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2005, 3, 20)),
#  ('Alonso', datetime.date(1981, 7, 29), 7586358, 'European Grand Prix', 'Nürburgring', datetime.date(2007, 7, 22)),
#  ('Alonso', datetime.date(1981, 7, 29), 6029329, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2007, 5, 27)),
#  ('Alonso', datetime.date(1981, 7, 29), 5534930, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2007, 4, 8)),
#  ('Alonso', datetime.date(1981, 7, 29), 5677308, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2006, 6, 25)),
#  ('Alonso', datetime.date(1981, 7, 29), 5465862, 'German Grand Prix', 'Hockenheimring', datetime.date(2012, 7, 22)),
#  ('Alonso', datetime.date(1981, 7, 29), 5421892, 'Japanese Grand Prix', 'Fuji Speedway', datetime.date(2008, 10, 12)),
#  ('Alonso', datetime.date(1981, 7, 29), 6256649, 'European Grand Prix', 'Valencia Street Circuit', datetime.date(2012, 6, 24)),
#  ('Alonso', datetime.date(1981, 7, 29), 9891812, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2012, 3, 25)),
#  ('Alonso', datetime.date(1981, 7, 29), 5786945, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2013, 4, 14)),
#  ('Alonso', datetime.date(1981, 7, 29), 5321196, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2011, 7, 10)),
#  ('Alonso', datetime.date(1981, 7, 29), 5956596, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2013, 5, 12)),
#  ('Alonso', datetime.date(1981, 7, 29), 10100810, 'Korean Grand Prix', 'Korean International Circuit', datetime.date(2010, 10, 24)),
#  ('Alonso', datetime.date(1981, 7, 29), 7073579, 'Singapore Grand Prix', 'Marina Bay Street Circuit', datetime.date(2010, 9, 26)),
#  ('Alonso', datetime.date(1981, 7, 29), 4584572, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2010, 9, 12)),
#  ('Alonso', datetime.date(1981, 7, 29), 5151927, 'British Grand Prix', 'Silverstone Circuit', datetime.date(2006, 6, 11)),
#  ('Alonso', datetime.date(1981, 7, 29), 5258864, 'German Grand Prix', 'Hockenheimring', datetime.date(2010, 7, 25)),
#  ('Alonso', datetime.date(1981, 7, 29), 5960396, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2010, 3, 14)),
#  ('Alonso', datetime.date(1981, 7, 29), 6223116, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2006, 5, 28)),
#  ('Alonso', datetime.date(1981, 7, 29), 5181759, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2006, 5, 14)),
#  ('Alonso', datetime.date(1981, 7, 29), 5667870, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2006, 4, 2)),
#  ('Alonso', datetime.date(1981, 7, 29), 5386205, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2006, 3, 12)),
#  ('Alonso', datetime.date(1981, 7, 29), 5941460, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2003, 8, 24)),
#  ('Alonso', datetime.date(1981, 7, 29), 5993618, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2005, 10, 16)),
#  ('Alonso', datetime.date(1981, 7, 29), 5188599, 'German Grand Prix', 'Hockenheimring', datetime.date(2005, 7, 24)),
#  ('Alonso', datetime.date(1981, 7, 29), 4717806, 'Italian Grand Prix', 'Autodromo Nazionale di Monza', datetime.date(2007, 9, 9)),
#  ('Alonso', datetime.date(1981, 7, 29), 5482232, 'French Grand Prix', 'Circuit de Nevers Magny-Cours', datetime.date(2005, 7, 3)),
#  ('Alonso', datetime.date(1981, 7, 29), 5506648, 'European Grand Prix', 'Nürburgring', datetime.date(2005, 5, 29)),
#  ('Alonso', datetime.date(1981, 7, 29), 5261921, 'San Marino Grand Prix', 'Autodromo Enzo e Dino Ferrari', datetime.date(2005, 4, 24)),
#  ('Alonso', datetime.date(1981, 7, 29), 5032413, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2006, 10, 8)),
#  ('Massa', datetime.date(1981, 4, 25), 5513751, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2006, 10, 22)),
#  ('Massa', datetime.date(1981, 4, 25), 5732339, 'European Grand Prix', 'Valencia Street Circuit', datetime.date(2008, 8, 24)),
#  ('Massa', datetime.date(1981, 4, 25), 5651435, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2008, 11, 2)),
#  ('Massa', datetime.date(1981, 4, 25), 5496230, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2007, 5, 13)),
#  ('Massa', datetime.date(1981, 4, 25), 5510245, 'French Grand Prix', 'Circuit de Nevers Magny-Cours', datetime.date(2008, 6, 22)),
#  ('Massa', datetime.date(1981, 4, 25), 5331082, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2006, 8, 27)),
#  ('Massa', datetime.date(1981, 4, 25), 5209451, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2008, 5, 11)),
#  ('Massa', datetime.date(1981, 4, 25), 5202161, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2007, 8, 26)),
#  ('Massa', datetime.date(1981, 4, 25), 5607515, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2007, 4, 15)),
#  ('Massa', datetime.date(1981, 4, 25), 5466970, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2008, 4, 6)),
#  ('Massa', datetime.date(1981, 4, 25), 4979394, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2008, 9, 7)),
#  ('Button', datetime.date(1980, 1, 19), 6322656, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', datetime.date(2012, 11, 25)),
#  ('Button', datetime.date(1980, 1, 19), 6402337, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2011, 7, 31)),
#  ('Button', datetime.date(1980, 1, 19), 5184848, 'Turkish Grand Prix', 'Istanbul Park', datetime.date(2009, 6, 7)),
#  ('Button', datetime.date(1980, 1, 19), 6044282, 'Monaco Grand Prix', 'Circuit de Monaco', datetime.date(2009, 5, 24)),
#  ('Button', datetime.date(1980, 1, 19), 14679537, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', datetime.date(2011, 6, 12)),
#  ('Button', datetime.date(1980, 1, 19), 5839202, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', datetime.date(2009, 5, 10)),
#  ('Button', datetime.date(1980, 1, 19), 6740941, 'Hungarian Grand Prix', 'Hungaroring', datetime.date(2006, 8, 6)),
#  ('Button', datetime.date(1980, 1, 19), 5508182, 'Bahrain Grand Prix', 'Bahrain International Circuit', datetime.date(2009, 4, 26)),
#  ('Button', datetime.date(1980, 1, 19), 4252092, 'Malaysian Grand Prix', 'Sepang International Circuit', datetime.date(2009, 4, 5)),
#  ('Button', datetime.date(1980, 1, 19), 5655784, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2009, 3, 29)),
#  ('Button', datetime.date(1980, 1, 19), 5348530, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', datetime.date(2012, 9, 2)),
#  ('Button', datetime.date(1980, 1, 19), 6402163, 'Chinese Grand Prix', 'Shanghai International Circuit', datetime.date(2010, 4, 18)),
#  ('Button', datetime.date(1980, 1, 19), 5616531, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2010, 3, 28)),
#  ('Button', datetime.date(1980, 1, 19), 5649565, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', datetime.date(2012, 3, 18)),
#  ('Button', datetime.date(1980, 1, 19), 5453427, 'Japanese Grand Prix', 'Suzuka Circuit', datetime.date(2011, 10, 9))]

# %% [markdown]
# ## Describe the query using EXPLAIN ANALYZE with at least 5 lines of text. Answer at least the following:
# * How many calls are you making?
# * How long does it take to perform the query?

# %%
# %sql EXPLAIN ANALYZE SELECT drivers.surname, drivers.dob, milliseconds, races.name AS race_name, circuits.name AS circuits_name, races.date AS race_date FROM results JOIN drivers ON drivers.dob > '1980-01-01' AND results.position = 1 AND drivers.driverid = results.driverid JOIN races USING (raceid) JOIN circuits ON circuits.circuitid = races.circuitid;
# Out:
# 18 rows affected.
# [('Nested Loop  (cost=25.68..785.35 rows=69 width=62) (actual time=0.110..2.407 rows=199 loops=1)',),
#  ('  ->  Nested Loop  (cost=25.54..773.21 rows=69 width=50) (actual time=0.106..2.236 rows=199 loops=1)',),
#  ('        ->  Hash Join  (cost=25.26..746.51 rows=69 width=27) (actual time=0.098..1.994 rows=199 loops=1)',),
#  ('              Hash Cond: (results.driverid = drivers.driverid)',),
#  ('              ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.005..1.803 rows=974 loops=1)',),
#  ('                    Filter: ("position" = 1)',),
#  ('                    Rows Removed by Filter: 22703',),
#  ('              ->  Hash  (cost=24.51..24.51 rows=60 width=19) (actual time=0.086..0.086 rows=61 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                    ->  Seq Scan on drivers  (cost=0.00..24.51 rows=60 width=19) (actual time=0.004..0.074 rows=61 loops=1)',),
#  ("                          Filter: (dob > '1980-01-01'::date)",),
#  ('                          Rows Removed by Filter: 780',),
#  ('        ->  Index Scan using idx_17199_primary on races  (cost=0.28..0.39 rows=1 width=39) (actual time=0.001..0.001 rows=1 loops=199)',),
#  ('              Index Cond: (raceid = results.raceid)',),
#  ('  ->  Index Scan using idx_17102_primary on circuits  (cost=0.14..0.18 rows=1 width=28) (actual time=0.001..0.001 rows=1 loops=199)',),
#  ('        Index Cond: (circuitid = races.circuitid)',),
#  ('Planning time: 0.413 ms',),
#  ('Execution time: 2.458 ms',)]

# %% [markdown]
# By looking at the query, we can see that postgres is doing mutliply things. It starts by setting up some nested loops. It then doing a hash join on the driverid's from the tables 'results' and 'drivers'. After that it is doing a sequential scan on the results to find only those who has postion = 1. It then doing a sequential scan on the drivers table, to check the date of birth. Then it uses an index scan on the raceid from the tables 'results' and 'races'. And again uses another index scan on the tables 'circuits' and 'races' to match the circuit id. In total we are making 7 calls which takes 2.458 ms

# %% [markdown]
# ## Create a materialized view of your query. Using EXPLAIN ANALYZE try to query the view. Write at least 5 lines of text explaining what's going on and why the query execution time changed.

# %%
# %sql CREATE VIEW race_winners AS SELECT drivers.surname, drivers.dob, milliseconds, races.name AS race_name, circuits.name AS circuits_name, races.date AS race_date FROM results JOIN drivers ON drivers.dob > '1980-01-01' AND results.position = 1 AND drivers.driverid = results.driverid JOIN races USING (raceid) JOIN circuits ON circuits.circuitid = races.circuitid;
# Out:
# Done.
# []

# %%
# %sql CREATE MATERIALIZED VIEW race_winners_cache AS SELECT * FROM race_winners;
# Out:
# 199 rows affected.
# []

# %%
# %sql EXPLAIN ANALYZE SELECT * FROM race_winners_cache;
# Out:
# 3 rows affected.
# [('Seq Scan on race_winners_cache  (cost=0.00..10.50 rows=50 width=1564) (actual time=0.009..0.024 rows=199 loops=1)',),
#  ('Planning time: 0.115 ms',),
#  ('Execution time: 0.041 ms',)]

# %% [markdown]
# Compared to the query before we materialized it, we are only making one call which takes only 0.041 ms. We are only making one sequential scan because our materialized view already contains all the information we want, so we only need to go through that data and show (select) it.
